# %%
def model_calculation(simulation_data):

  #qaid and mary's part

print("calculated result:\n", calculated_result)
  plt.figure(figsize=(10, 6)) # sizing the plot figure
  step_size = max(1, len(t_grid) // 10) # choosing the amount of steps of time we will plot. 10 lines

  for t in range(0, len(t_grid), step_size):
      plt.plot(x_grid, calculated_result[t, :], label=f'Time {t_grid[t]:.0f}s') # creating concentration vs space plot, for 10 line plots of time

  plt.title(f"Pollutant Evolution: {title}")
  plt.xlabel("Distance (m)")
  plt.ylabel("Concentration")
  plt.legend()
  plt.grid(True)
  plt.show()

  plt.subplot(2, 1, 2)
  # extent=[x_min, x_max, t_max, t_min] puts Time 0 at the top
  plt.imshow(calculated_result, aspect='auto', extent=[x_grid[0], x_grid[-1], t_grid[-1], t_grid[0]], cmap='viridis') # creating heatmap plot
  plt.colorbar(label='Concentration')
  plt.title("Spacetime Heatmap")
  plt.xlabel("Distance (m)")
  plt.ylabel("Time (s)")

  plt.tight_layout()
  plt.show()

simulation_data = user_inputs();
model_calculation(simulation_data);
